# %% [markdown]
# <h1>Innholdsfortegnelse</h1>
#
# - [0 Systemsjekk og kalender](#0-Systemsjekk-og-kalender)
#     - [0.1 Systemsjekk](#0.1-Systemsjekk)
#     - [0.2 Kalender](#0.2-Kalender)
# - [1 Grunnleggende regning](#1.0-Grunnleggende-regning)
#     - [1.1 Hoderegning](#1.1-Hoderegning)
#     - [1.2 Multiplikasjon og divisjon](#1.2-Multiplikasjon-og-divisjon)
#     - [1.3 Overslagsregning](#1.3-Overslagsregning)
#     - [1.4 Brok](#1.4-Brok)
#     - [1.5 Regne med brok](#1.5-Regne-med-brok)
#     - [1.6 Prosent](#1.6-Prosent)
#     - [1.7 Prosentvis endring](#1.7-Prosentvis-endring)
# - [2 Personlig okonomi](#2-Personlig-okonomi)
#     - [2.1 Regneark](#2.1-Regneark)
#     - [2.2 Lonn og skatt](#2.2-Lonn-og-skatt)
#     - [2.3 Sparing](#2.3-Sparing)
#     - [2.4 Lan](#2.4-Lan)
#     - [2.5 Kredittkort](#2.5-Kredittkort)
#     - [2.6 Okonomiske valg](#2.6-Okonomiske-valg)
# - [3 Formler og geometri](#3-Formler-og-geometri)
#     - [3.1 Formlerregning](#3.1-Formlerregning)
#     - [3.2 Formler og likninger](#3.2-Formler-og-likninger)
#     - [3.3 Enheter](#3.3-Enheter)
#     - [3.4 Forhold](#3.4-Forhold)
#     - [3.5 Formlikhet](#3.5-Formlikhet)
#     - [3.6 Pytagoras](#3.6-Pytagoras)
#     - [3.7 Areal](#3.7-Areal)
#     - [3.8 Volum og overflateareal](#3.8-Volum-og-overflateareal)
#     - [3.9 Design og produktutvikling](#3.9-Design-og-produktutvikling)
# - [4 Statistikk](#4-Statistikk)
#     - [4.1 Tabeller og grafiske framstillinger](#4.1-Tabeller-og-grafiske-framstillinger)
#     - [4.2 Soylediagrammer og sektordiagrammer](#4.2-Soylediagrammer-og-sektordiagrammer)
#     - [4.3 Linjediagrammer](#4.3-Linjediagrammer)
#     - [4.4 Ulike framstillinger av statistisk datamateriale](#4.4-Ulike-framstillinger-av-statistisk-datamateriale)
#     - [4.5 Statistiske undersokelser](#4.5-Statistiske-undersokelser)
#     - [4.6 Storre datamengder](#4.6-Større-datamengder)
# - [5 Yrkesokonomi](#5-Yrkesokonomi)
#     - [5.1 Inntekter og kostnader](#5.1-Inntekter-og-kostnader)
#     - [5.2 Merverdiavgift](#5.2-Merverdiavgift)
#     - [5.3 Priskalkyler](#5.3-Priskalkyler)
#     - [5.4 Budsjett](#5.4-Budsjett)
#     - [5.5 Anbud](#5.5-Anbud)

# %% [markdown]
# # 0 Systemsjekk og kalender
# <p><em>Fyll inn innhold her</em></p>
#
# <a href="#Innholdsfortegnelse">⬆ Tilbake til innholdsfortegnelse</a>

# %% [markdown]
# ## 0.1 Systemsjekk
# <a href="#Innholdsfortegnelse">⬆ Tilbake til innholdsfortegnelse</a>

# %% [markdown]
# ## 0.2 Kalender
# <a href="#Innholdsfortegnelse">⬆ Tilbake til innholdsfortegnelse</a>

# %% [markdown]
# # 1 Grunnleggende regning
# <a id='1.0-Grunnleggende-regning'></a>
# <p><em>Fyll inn innhold her</em></p>
#
# <a href="#Innholdsfortegnelse">⬆ Tilbake til innholdsfortegnelse</a>

# %% [markdown]
# ## 1.1 Hoderegning
# <a href="#Innholdsfortegnelse">⬆ Tilbake til innholdsfortegnelse</a>

# %% [markdown]
# ## 1.2 Multiplikasjon og divisjon
# <a href="#Innholdsfortegnelse">⬆ Tilbake til innholdsfortegnelse</a>

# %% [markdown]
# ## 1.3 Overslagsregning
# <a href="#Innholdsfortegnelse">⬆ Tilbake til innholdsfortegnelse</a>

# %% [markdown]
# ## 1.4 Brok
# <a href="#Innholdsfortegnelse">⬆ Tilbake til innholdsfortegnelse</a>

# %% [markdown]
# ## 1.5 Regne med brok
# <a href="#Innholdsfortegnelse">⬆ Tilbake til innholdsfortegnelse</a>

# %% [markdown]
# ## 1.6 Prosent
# <a href="#Innholdsfortegnelse">⬆ Tilbake til innholdsfortegnelse</a>

# %% [markdown]
# ## 1.7 Prosentvis endring
# <a href="#Innholdsfortegnelse">⬆ Tilbake til innholdsfortegnelse</a>

# %% [markdown]
# # 2 Personlig okonomi
# <a id='2-Personlig-okonomi'></a>
# <p><em>Fyll inn innhold her</em></p>
#
# <a href="#Innholdsfortegnelse">⬆ Tilbake til innholdsfortegnelse</a>

# %% [markdown]
# ## 2.1 Regneark
# <a href="#Innholdsfortegnelse">⬆ Tilbake til innholdsfortegnelse</a>

# %% [markdown]
# ## 2.2 Lonn og skatt
# <a href="#Innholdsfortegnelse">⬆ Tilbake til innholdsfortegnelse</a>

# %% [markdown]
# ## 2.3 Sparing
# <a href="#Innholdsfortegnelse">⬆ Tilbake til innholdsfortegnelse</a>

# %% [markdown]
# ## 2.4 Lan
# <a href="#Innholdsfortegnelse">⬆ Tilbake til innholdsfortegnelse</a>

# %% [markdown]
# ## 2.5 Kredittkort
# <a href="#Innholdsfortegnelse">⬆ Tilbake til innholdsfortegnelse</a>

# %% [markdown]
# ## 2.6 Okonomiske valg
# <a href="#Innholdsfortegnelse">⬆ Tilbake til innholdsfortegnelse</a>

# %% [markdown]
# # 3 Formler og geometri
# <a id='2-Personlig-okonomi'></a>
# <p><em>Fyll inn innhold her</em></p>
#
# <a href="#Innholdsfortegnelse">⬆ Tilbake til innholdsfortegnelse</a>

# %% [markdown]
# ## 3.1 Formlerregning
# <a href="#Innholdsfortegnelse">⬆ Tilbake til innholdsfortegnelse</a>

# %% [markdown]
# ## 3.2 Formler og likninger
# <a href="#Innholdsfortegnelse">⬆ Tilbake til innholdsfortegnelse</a>

# %% [markdown]
# ## 3.3 Enheter
# <a href="#Innholdsfortegnelse">⬆ Tilbake til innholdsfortegnelse</a>

# %% [markdown]
# ## 3.4 Forhold
# <a href="#Innholdsfortegnelse">⬆ Tilbake til innholdsfortegnelse</a>

# %% [markdown]
# ## 3.5 Formlikhet
# <a href="#Innholdsfortegnelse">⬆ Tilbake til innholdsfortegnelse</a>

# %% [markdown]
# ## 3.6 Pytagoras
# <a href="#Innholdsfortegnelse">⬆ Tilbake til innholdsfortegnelse</a>

# %% [markdown]
# ## 3.7 Areal
# <a href="#Innholdsfortegnelse">⬆ Tilbake til innholdsfortegnelse</a>

# %% [markdown]
# ## 3.8 Volum og overflateareal
# <a href="#Innholdsfortegnelse">⬆ Tilbake til innholdsfortegnelse</a>

# %% [markdown]
# ## 3.9 Design og produktutvikling
# <a href="#Innholdsfortegnelse">⬆ Tilbake til innholdsfortegnelse</a>

# %% [markdown]
# # 4 Statistikk
# <a id='4-Statistikk'></a>
# <p><em>Fyll inn innhold her</em></p>
#
# <a href="#Innholdsfortegnelse">⬆ Tilbake til innholdsfortegnelse</a>

# %% [markdown]
# ## 4.1 Tabeller og grafiske framstillinger
# <a href="#Innholdsfortegnelse">⬆ Tilbake til innholdsfortegnelse</a>

# %% [markdown]
# ## 4.2 Soylediagrammer og sektordiagrammer
# <a href="#Innholdsfortegnelse">⬆ Tilbake til innholdsfortegnelse</a>

# %% [markdown]
# ## 4.3 Linjediagrammer
# <a href="#Innholdsfortegnelse">⬆ Tilbake til innholdsfortegnelse</a>

# %% [markdown]
# ## 4.4 Ulike framstillinger av statistisk datamateriale
# <a href="#Innholdsfortegnelse">⬆ Tilbake til innholdsfortegnelse</a>

# %% [markdown]
# ## 4.5 Statistiske undersokelser
# <a href="#Innholdsfortegnelse">⬆ Tilbake til innholdsfortegnelse</a>

# %% [markdown]
# ## 4.6 Storre datamengder
# <a href="#Innholdsfortegnelse">⬆ Tilbake til innholdsfortegnelse</a>

# %% [markdown]
# # 5 Yrkesokonomi
# <a id='5-Yrkesokonomi'></a>
# <p><em>Fyll inn innhold her</em></p>
#
# <a href="#Innholdsfortegnelse">⬆ Tilbake til innholdsfortegnelse</a>

# %% [markdown]
# ## 5.1 Inntekter og kostnader
# <a href="#Innholdsfortegnelse">⬆ Tilbake til innholdsfortegnelse</a>

# %% [markdown]
# ## 5.2 Merverdiavgift
# <a href="#Innholdsfortegnelse">⬆ Tilbake til innholdsfortegnelse</a>

# %% [markdown]
# ## 5.3 Priskalkyler
# <a href="#Innholdsfortegnelse">⬆ Tilbake til innholdsfortegnelse</a>

# %% [markdown]
# ## 5.4 Budsjett
# <a href="#Innholdsfortegnelse">⬆ Tilbake til innholdsfortegnelse</a>

# %% [markdown]
# ## 5.5 Anbud
# <a href="#Innholdsfortegnelse">⬆ Tilbake til innholdsfortegnelse</a>
